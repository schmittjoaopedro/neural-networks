# %% [markdown]
# # Building your own Object Detector from scratch
#
# This notebook has educational purposes only.
#
# It shows how to build a simple Object Detector from scratch using Tensorflow & Keras.
#
# The model is trained over the Labeled Mask database.
#
# Check this story on medium for more details: https://medium.com/@doleron/building-your-own-object-detector-from-scratch-bfeadfaddad8

# %% [markdown]
# ## Getting the data
#
# Before run this notebook, it is necessary to download the archive file with the training images and respective annotation files.
#
# The file is available on Kaggle: https://www.kaggle.com/datasets/techzizou/labeled-mask-dataset-yolo-darknet
#
# Hit the download button and copy the `archive.zip` to the `data` folder. After that, run the next cell.

# %%
import pathlib
import shutil

data_dir_path = "datasets/"
#shutil.unpack_archive(data_dir_path + "/archive.zip", data_dir_path)

data_dir = pathlib.Path(data_dir_path + "/obj/").with_suffix('')

image_files = list(data_dir.glob('*.jpg'))
print(len(image_files))
# Out:
# 1510

# %% [markdown]
# The previous cell uncompress the `archive.zip` file and store the images & text files in the `data/obj` folder. We can inspect the contents of those files as shown below:

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
sample_img_path = str(image_files[93])
print(sample_img_path)
sample_img = cv.imread(sample_img_path, cv.IMREAD_COLOR)
plt.imshow(cv.cvtColor(sample_img, cv.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
# Out:
# datasets/obj/357-with-mask.jpg

# %% [markdown]
# Basically, the data consist of images files and respective annotation files. Each annotation file has one or more lines in which we can find the class and bounding box coordinates:

# %%
sample_annotation_path = sample_img_path[0:-4] + '.txt'
with open(sample_annotation_path) as f:
    print(f.readlines())
# Out:
# ['0 0.4671875 0.6051401869158879 0.671875 0.514018691588785\n']

# %% [markdown]
# The following function filter the files, generating 3 lists:
#
# - training files (70% of images)
# - validation files (20% of images)
# - test files (last 10%)

# %%
import os, random

def list_files(full_data_path = "datasets/obj/", image_ext = '.jpg', split_percentage = [70, 20]):
    

    files = []

    discarded = 0
    masked_instance = 0

    for r, d, f in os.walk(full_data_path):
        for file in f:
            if file.endswith(".txt"):

                # first, let's check if there is only one object
                with open(full_data_path + "/" + file, 'r') as fp: 
                    lines = fp.readlines()
                    if len(lines) > 1:
                        discarded += 1
                        continue
                    

                strip = file[0:len(file) - len(".txt")]  
                # secondly, check if the paired image actually exist
                image_path = full_data_path + "/" + strip + image_ext
                if os.path.isfile(image_path):
                    # checking the class. '0' means masked, '1' for unmasked
                    if lines[0][0] == '0':
                        masked_instance += 1
                    files.append(strip)

    size = len(files)   
    print(str(discarded) + " file(s) discarded")
    print(str(size) + " valid case(s)")
    print(str(masked_instance) + " are masked cases")

    random.shuffle(files)

    split_training = int(split_percentage[0] * size / 100)
    split_validation = split_training + int(split_percentage[1] * size / 100)

    return files[0:split_training], files[split_training:split_validation], files[split_validation:]

# %%
training_files, validation_files, test_files = list_files()

print(str(len(training_files)) + " training files")
print(str(len(validation_files)) + " validation files")
print(str(len(test_files)) + " test files")
# Out:
# 218 file(s) discarded
# 1292 valid case(s)
# 832 are masked cases
# 904 training files
# 258 validation files
# 130 test files

# %% [markdown]
# This is actually a small dataset. We have only 904 images to train our model!
#
# Let's combine image and annotations in order to check if we actually understand how to deal with the data.
#
# In addition, let's format the images for the input size of our model (244 x 244)

# %%
input_size = 244

def format_image(img, box):
    height, width = img.shape 
    max_size = max(height, width)
    r = max_size / input_size
    new_width = int(width / r)
    new_height = int(height / r)
    new_size = (new_width, new_height)
    resized = cv.resize(img, new_size, interpolation= cv.INTER_LINEAR)
    new_image = np.zeros((input_size, input_size), dtype=np.uint8)
    new_image[0:new_height, 0:new_width] = resized

    x, y, w, h = box[0], box[1], box[2], box[3]
    new_box = [int((x - 0.5*w)* width / r), int((y - 0.5*h) * height / r), int(w*width / r), int(h*height / r)]

    return new_image, new_box

# %%
temp_img = cv.imread("datasets/obj/5-with-mask.jpg", cv.IMREAD_GRAYSCALE)
temp_box = [0.38183279742765275, 0.6171428571428571, 0.43569131832797425, 0.6285714285714286]

temp_img_formated, box = format_image(temp_img, temp_box)

temp_color_img = cv.cvtColor(temp_img_formated, cv.COLOR_GRAY2RGB)

cv.rectangle(temp_color_img, box, (0, 255, 0), 2)

plt.imshow(temp_color_img)
plt.axis("off")
plt.show()

# %%
temp_img = cv.imread("datasets/obj/149.jpg", cv.IMREAD_GRAYSCALE)
temp_box = [0.5171875, 0.5911214953271028, 0.621875, 0.6495327102803738]

temp_img_formated, box = format_image(temp_img, temp_box)

temp_color_img = cv.cvtColor(temp_img_formated, cv.COLOR_GRAY2RGB)

cv.rectangle(temp_color_img, box, (0, 0, 255), 2)

plt.imshow(temp_color_img)
plt.axis("off")
plt.show()

# %% [markdown]
# The dataset is composed by different images of people using or not masks. Let's create a tensorflow dataset with the images:

# %%
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' # disabling verbose tf logging

# uncomment the following line if you want to force CPU
# os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import tensorflow as tf
print(tf.__version__)
# Out:
# 2.16.1

# %%
def data_load(files, full_data_path = "datasets/obj/", image_ext = ".jpg"):
    X = []
    Y = []

    for file in files:
        img = cv.imread(os.path.join(full_data_path, file + image_ext), cv.IMREAD_GRAYSCALE)

        k = 1

        with open(full_data_path + "/" + file + ".txt", 'r') as fp: 
            line = fp.readlines()[0]
            if line[0] == '0':
                k = 0

            box = np.array(line[1:].split(), dtype=float)

        img, box = format_image(img, box)
        img = img.astype(float) / 255.
        box = np.asarray(box, dtype=float) / input_size
        label = np.append(box, k)

        X.append(img)
        Y.append(label)

    X = np.array(X)
    
    X = np.expand_dims(X, axis=3)

    X = tf.convert_to_tensor(X, dtype=tf.float32)

    Y = tf.convert_to_tensor(Y, dtype=tf.float32)

    result = tf.data.Dataset.from_tensor_slices((X, Y))

    return result

# %%
raw_train_ds = data_load(training_files)

# %%
raw_validation_ds = data_load(validation_files)

# %%
raw_test_ds = data_load(test_files)

# %% [markdown]
# The training, validation & test datasets must be set up in order to follow the tensorflow guideline (https://www.tensorflow.org/datasets/performances):

# %%
CLASSES = 2

def format_instance(image, label):
    return image, (tf.one_hot(int(label[4]), CLASSES), [label[0], label[1], label[2], label[3]])

# %%
BATCH_SIZE = 32

# see https://www.tensorflow.org/guide/data_performance

def tune_training_ds(dataset):
    dataset = dataset.map(format_instance, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.shuffle(1024, reshuffle_each_iteration=True)
    dataset = dataset.repeat() # The dataset be repeated indefinitely.
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %%
train_ds = tune_training_ds(raw_train_ds)

# %%
def tune_validation_ds(dataset):
    dataset = dataset.map(format_instance, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(len(validation_files) // 4)
    dataset = dataset.repeat()
    return dataset

# %%
validation_ds = tune_validation_ds(raw_validation_ds)

# %% [markdown]
# Let's inspect our training dataset:

# %%
plt.figure(figsize=(20, 10))
for images, labels in train_ds.take(1):
    for i in range(BATCH_SIZE):
        ax = plt.subplot(4, BATCH_SIZE//4, i + 1)
        label = labels[0][i]
        box = (labels[1][i] * input_size)
        box = tf.cast(box, tf.int32)

        image = images[i].numpy().astype("float") * 255.0
        image = image.astype(np.uint8)
        image_color = cv.cvtColor(image, cv.COLOR_GRAY2RGB)

        color = (0, 0, 255)
        if label[0] > 0:
            color = (0, 255, 0)

        cv.rectangle(image_color, box.numpy(), color, 2)

        plt.imshow(image_color)
        plt.axis("off")

# %% [markdown]
# Based on the image above, we can realize that the training dataset is correctly set. Blue rectangles represent bounding box of **unmask people**. A green rectangle represent a masked person.
#
# Once the data is ready, we can start our modelling and training.

# %% [markdown]
# ## The model
#
# Since we are building a object detector, our model have two heads: one to classify the object type (or label or class) and other head to output the object bounding box. In order to achieve that, we use Tensorflow Funcional API, as follows:

# %%
DROPOUT_FACTOR = 0.5

def build_feature_extractor(inputs):

    x = tf.keras.layers.Conv2D(16, kernel_size=3, activation='relu', input_shape=(input_size, input_size, 1))(inputs)
    x = tf.keras.layers.AveragePooling2D(2,2)(x)

    x = tf.keras.layers.Conv2D(32, kernel_size=3, activation = 'relu')(x)
    x = tf.keras.layers.AveragePooling2D(2,2)(x)

    x = tf.keras.layers.Conv2D(64, kernel_size=3, activation = 'relu')(x)
    x = tf.keras.layers.Dropout(DROPOUT_FACTOR)(x)
    x = tf.keras.layers.AveragePooling2D(2,2)(x)

    return x

def build_model_adaptor(inputs):
    x = tf.keras.layers.Flatten()(inputs)
    x = tf.keras.layers.Dense(64, activation='relu')(x)
    return x

def build_classifier_head(inputs):
    return tf.keras.layers.Dense(CLASSES, activation='softmax', name = 'classifier_head')(inputs)

def build_regressor_head(inputs):
    return tf.keras.layers.Dense(units = 4, name = 'regressor_head')(inputs)

def build_model(inputs):
    
    feature_extractor = build_feature_extractor(inputs)

    model_adaptor = build_model_adaptor(feature_extractor)

    classification_head = build_classifier_head(model_adaptor)

    regressor_head = build_regressor_head(model_adaptor)

    model = tf.keras.Model(inputs = inputs, outputs = [classification_head, regressor_head])

    model.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss = {'classifier_head' : 'categorical_crossentropy', 'regressor_head' : 'mse' }, 
              metrics = {'classifier_head' : 'accuracy', 'regressor_head' : 'mse' })

    return model

# %% [markdown]
# It is notewhortly that each network head has a specific set of loss function and metrics:

# %%
model = build_model(tf.keras.layers.Input(shape=(input_size, input_size, 1,)))

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 244, 244,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 242, 242,  │        160 │ input_layer_1[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_3 │ (None, 121, 121,  │          0 │ conv2d_3[0][0]    │
# │ (AveragePooling2D)  │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 119, 119,  │      4,640 │ average_pooling2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_4 │ (None, 59, 59,    │          0 │ conv2d_4[0][0]    │
# │ (AveragePooling2D)  │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 57, 57,    │     18,496 │ average_pooling2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 57, 57,    │          0 │ conv2d_5[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_5 │ (None, 28, 28,    │          0 │ dropout_1[0][0]   │
# │ (AveragePooling2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 50176)     │          0 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │  3,211,328 │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classifier_head     │ (None, 2)         │        130 │ dense_1[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ regressor_head      │ (None, 4)         │        260 │ dense_1[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,235,014 (12.34 MB)
#  Trainable params: 3,235,014 (12.34 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Since we have few data, we must keep the model small. The model can be vizualized below:

# %%
# plot_model requires graphviz & pydot
# see https://github.com/XifengGuo/CapsNet-Keras/issues/7#issuecomment-370745440
from tensorflow.keras.utils import plot_model

plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %% [markdown]
# ## Model training
#
# Our model is all set and we can start the training, as shown in the next cell:

# %%
EPOCHS = 100

history = model.fit(train_ds,
                    steps_per_epoch=(len(training_files) // BATCH_SIZE),
                    validation_data=validation_ds, validation_steps=1, 
                    epochs=EPOCHS)
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 233ms/step - classifier_head_accuracy: 0.5596 - loss: 1.4977 - regressor_head_mse: 0.5191 - val_classifier_head_accuracy: 0.5781 - val_loss: 0.7036 - val_regressor_head_mse: 0.0233
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 231ms/step - classifier_head_accuracy: 0.6660 - loss: 0.6075 - regressor_head_mse: 0.0256 - val_classifier_head_accuracy: 0.6250 - val_loss: 0.6531 - val_regressor_head_mse: 0.0109
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 226ms/step - classifier_head_accuracy: 0.7450 - loss: 0.5390 - regressor_head_mse: 0.0153 - val_classifier_head_accuracy: 0.7812 - val_loss: 0.5527 - val_regressor_head_mse: 0.0145
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 229ms/step - classifier_head_accuracy: 0.7739 - loss: 0.4912 - regressor_head_mse: 0.0167 - val_classifier_head_accuracy: 0.7969 - val_loss: 0.4774 - val_regressor_head_mse: 0.0187
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - classifier_head_accuracy: 0.8518 - loss: 0.3915 - regressor_head_mse: 0.0182 - val_classifier_head_accuracy: 0.5000 - val_loss: 1.1789 - val_regressor_head_mse: 0.0239
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 232ms/step - classifier_head_accuracy: 0.8857 - loss: 0.3363 - regressor_head_mse: 0.0191 - val_classifier_head_accuracy: 0.7812 - val_loss: 0.5553 - val_regressor_head_mse: 0.0257
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 231ms/step - classifier_head_accuracy: 0.9030 - loss: 0.2798 - regressor_head_mse: 0.0187 - val_classifier_head_accuracy: 0.7344 - val_loss: 0.5382 - val_regressor_head_mse: 0.0217
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - classifier_head_accuracy: 0.9420 - loss: 0.1914 - regressor_head_mse: 0.0147 - val_classifier_head_accuracy: 0.8281 - val_loss: 0.4059 - val_regressor_head_mse: 0.0211
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - classifier_head_accuracy: 0.9441 - loss: 0.1582 - regressor_head_mse: 0.0127 - val_classifier_head_accuracy: 0.8438 - val_loss: 0.3514 - val_regressor_head_mse: 0.0193
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - classifier_head_accuracy: 0.9561 - loss: 0.1350 - regressor_head_mse: 0.0131 - val_classifier_head_accuracy: 0.5000 - val_loss: 3.5036 - val_regressor_head_mse: 0.0199
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - classifier_head_accuracy: 0.9742 - loss: 0.0918 - regressor_head_mse: 0.0135 - val_classifier_head_accuracy: 0.8281 - val_loss: 0.5836 - val_regressor_head_mse: 0.0181
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - classifier_head_accuracy: 0.9792 - loss: 0.0917 - regressor_head_mse: 0.0124 - val_classifier_head_accuracy: 0.8125 - val_loss: 0.7044 - val_regressor_head_mse: 0.0196
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - classifier_head_accuracy: 0.9692 - loss: 0.0926 - regressor_head_mse: 0.0167 - val_classifier_head_accuracy: 0.8438 - val_loss: 0.3844 - val_regressor_head_mse: 0.0205
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 229ms/step - classifier_head_accuracy: 0.9896 - loss: 0.0656 - regressor_head_mse: 0.0123 - val_classifier_head_accuracy: 0.8438 - val_loss: 0.4303 - val_regressor_head_mse: 0.0209
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - classifier_head_accuracy: 0.9835 - loss: 0.0700 - regressor_head_mse: 0.0152 - val_classifier_head_accuracy: 0.5000 - val_loss: 1.5501 - val_regressor_head_mse: 0.0152
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 263ms/step - classifier_head_accuracy: 0.9663 - loss: 0.1181 - regressor_head_mse: 0.0139 - val_classifier_head_accuracy: 0.7344 - val_loss: 0.7352 - val_regressor_head_mse: 0.0194
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 272ms/step - classifier_head_accuracy: 0.9847 - loss: 0.0597 - regressor_head_mse: 0.0097 - val_classifier_head_accuracy: 0.7969 - val_loss: 0.7310 - val_regressor_head_mse: 0.0183
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - classifier_head_accuracy: 0.9871 - loss: 0.0515 - regressor_head_mse: 0.0095 - val_classifier_head_accuracy: 0.8438 - val_loss: 0.4444 - val_regressor_head_mse: 0.0190
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - classifier_head_accuracy: 0.9836 - loss: 0.0518 - regressor_head_mse: 0.0077 - val_classifier_head_accuracy: 0.8594 - val_loss: 0.5815 - val_regressor_head_mse: 0.0213
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - classifier_head_accuracy: 0.9919 - loss: 0.0361 - regressor_head_mse: 0.0070 - val_classifier_head_accuracy: 0.5000 - val_loss: 5.7508 - val_regressor_head_mse: 0.0151
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 294ms/step - classifier_head_accuracy: 0.9962 - loss: 0.0287 - regressor_head_mse: 0.0067 - val_classifier_head_accuracy: 0.8281 - val_loss: 1.0138 - val_regressor_head_mse: 0.0178
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - classifier_head_accuracy: 0.9887 - loss: 0.0317 - regressor_head_mse: 0.0073 - val_classifier_head_accuracy: 0.8281 - val_loss: 0.9270 - val_regressor_head_mse: 0.0194
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 231ms/step - classifier_head_accuracy: 0.9907 - loss: 0.0327 - regressor_head_mse: 0.0069 - val_classifier_head_accuracy: 0.8438 - val_loss: 0.4675 - val_regressor_head_mse: 0.0154
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 259ms/step - classifier_head_accuracy: 0.9896 - loss: 0.0385 - regressor_head_mse: 0.0069 - val_classifier_head_accuracy: 0.8594 - val_loss: 0.6060 - val_regressor_head_mse: 0.0188
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - classifier_head_accuracy: 0.9971 - loss: 0.0196 - regressor_head_mse: 0.0069 - val_classifier_head_accuracy: 0.5000 - val_loss: 7.1593 - val_regressor_head_mse: 0.0227
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 294ms/step - classifier_head_accuracy: 0.9996 - loss: 0.0144 - regressor_head_mse: 0.0070 - val_classifier_head_accuracy: 0.8125 - val_loss: 1.0917 - val_regressor_head_mse: 0.0175
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - classifier_head_accuracy: 0.9952 - loss: 0.0209 - regressor_head_mse: 0.0077 - val_classifier_head_accuracy: 0.8125 - val_loss: 1.0024 - val_regressor_head_mse: 0.0177
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - classifier_head_accuracy: 0.9952 - loss: 0.0244 - regressor_head_mse: 0.0074 - val_classifier_head_accuracy: 0.8438 - val_loss: 0.5192 - val_regressor_head_mse: 0.0163
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - classifier_head_accuracy: 0.9963 - loss: 0.0164 - regressor_head_mse: 0.0064 - val_classifier_head_accuracy: 0.8281 - val_loss: 0.6606 - val_regressor_head_mse: 0.0201
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - classifier_head_accuracy: 0.9910 - loss: 0.0470 - regressor_head_mse: 0.0069 - val_classifier_head_accuracy: 0.5000 - val_loss: 6.0328 - val_regressor_head_mse: 0.0184
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 229ms/step - classifier_head_accuracy: 0.9879 - loss: 0.0411 - regressor_head_mse: 0.0064 - val_classifier_head_accuracy: 0.7969 - val_loss: 1.1773 - val_regressor_head_mse: 0.0205
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - classifier_head_accuracy: 0.9866 - loss: 0.0440 - regressor_head_mse: 0.0098 - val_classifier_head_accuracy: 0.7812 - val_loss: 0.9888 - val_regressor_head_mse: 0.0203
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 231ms/step - classifier_head_accuracy: 0.9908 - loss: 0.0294 - regressor_head_mse: 0.0091 - val_classifier_head_accuracy: 0.8594 - val_loss: 0.4823 - val_regressor_head_mse: 0.0137
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - classifier_head_accuracy: 0.9957 - loss: 0.0172 - regressor_head_mse: 0.0065 - val_classifier_head_accuracy: 0.8438 - val_loss: 0.5788 - val_regressor_head_mse: 0.0208
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0136 - regressor_head_mse: 0.0057 - val_classifier_head_accuracy: 0.5000 - val_loss: 6.9271 - val_regressor_head_mse: 0.0101
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 254ms/step - classifier_head_accuracy: 0.9973 - loss: 0.0112 - regressor_head_mse: 0.0046 - val_classifier_head_accuracy: 0.7969 - val_loss: 1.0009 - val_regressor_head_mse: 0.0148
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 271ms/step - classifier_head_accuracy: 0.9994 - loss: 0.0115 - regressor_head_mse: 0.0054 - val_classifier_head_accuracy: 0.8125 - val_loss: 1.0295 - val_regressor_head_mse: 0.0158
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - classifier_head_accuracy: 0.9955 - loss: 0.0241 - regressor_head_mse: 0.0061 - val_classifier_head_accuracy: 0.8594 - val_loss: 0.5664 - val_regressor_head_mse: 0.0157
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - classifier_head_accuracy: 0.9940 - loss: 0.0228 - regressor_head_mse: 0.0059 - val_classifier_head_accuracy: 0.8438 - val_loss: 0.6846 - val_regressor_head_mse: 0.0190
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - classifier_head_accuracy: 0.9805 - loss: 0.0741 - regressor_head_mse: 0.0069 - val_classifier_head_accuracy: 0.5000 - val_loss: 6.0897 - val_regressor_head_mse: 0.0250
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 231ms/step - classifier_head_accuracy: 0.9877 - loss: 0.0329 - regressor_head_mse: 0.0059 - val_classifier_head_accuracy: 0.7969 - val_loss: 0.8967 - val_regressor_head_mse: 0.0161
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - classifier_head_accuracy: 0.9980 - loss: 0.0123 - regressor_head_mse: 0.0042 - val_classifier_head_accuracy: 0.8281 - val_loss: 1.0124 - val_regressor_head_mse: 0.0177
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - classifier_head_accuracy: 0.9980 - loss: 0.0121 - regressor_head_mse: 0.0042 - val_classifier_head_accuracy: 0.8594 - val_loss: 0.5622 - val_regressor_head_mse: 0.0173
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0073 - regressor_head_mse: 0.0042 - val_classifier_head_accuracy: 0.8594 - val_loss: 0.6173 - val_regressor_head_mse: 0.0166
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - classifier_head_accuracy: 0.9966 - loss: 0.0128 - regressor_head_mse: 0.0036 - val_classifier_head_accuracy: 0.5000 - val_loss: 7.2805 - val_regressor_head_mse: 0.0146
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 267ms/step - classifier_head_accuracy: 0.9977 - loss: 0.0129 - regressor_head_mse: 0.0045 - val_classifier_head_accuracy: 0.8125 - val_loss: 1.0551 - val_regressor_head_mse: 0.0150
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - classifier_head_accuracy: 0.9981 - loss: 0.0148 - regressor_head_mse: 0.0040 - val_classifier_head_accuracy: 0.7812 - val_loss: 1.0542 - val_regressor_head_mse: 0.0133
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 226ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0094 - regressor_head_mse: 0.0037 - val_classifier_head_accuracy: 0.8594 - val_loss: 0.5856 - val_regressor_head_mse: 0.0149
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - classifier_head_accuracy: 0.9973 - loss: 0.0099 - regressor_head_mse: 0.0040 - val_classifier_head_accuracy: 0.8750 - val_loss: 0.6213 - val_regressor_head_mse: 0.0161
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - classifier_head_accuracy: 0.9973 - loss: 0.0123 - regressor_head_mse: 0.0039 - val_classifier_head_accuracy: 0.5000 - val_loss: 7.8856 - val_regressor_head_mse: 0.0112
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - classifier_head_accuracy: 0.9987 - loss: 0.0066 - regressor_head_mse: 0.0030 - val_classifier_head_accuracy: 0.7969 - val_loss: 1.0829 - val_regressor_head_mse: 0.0137
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 229ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0055 - regressor_head_mse: 0.0029 - val_classifier_head_accuracy: 0.8281 - val_loss: 1.1620 - val_regressor_head_mse: 0.0152
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0050 - regressor_head_mse: 0.0027 - val_classifier_head_accuracy: 0.8438 - val_loss: 0.5694 - val_regressor_head_mse: 0.0126
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0053 - regressor_head_mse: 0.0034 - val_classifier_head_accuracy: 0.8594 - val_loss: 0.6865 - val_regressor_head_mse: 0.0162
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 282ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0060 - regressor_head_mse: 0.0030 - val_classifier_head_accuracy: 0.5000 - val_loss: 7.8024 - val_regressor_head_mse: 0.0077
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 288ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0047 - regressor_head_mse: 0.0032 - val_classifier_head_accuracy: 0.7969 - val_loss: 1.1528 - val_regressor_head_mse: 0.0141
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - classifier_head_accuracy: 0.9988 - loss: 0.0055 - regressor_head_mse: 0.0026 - val_classifier_head_accuracy: 0.7812 - val_loss: 1.1871 - val_regressor_head_mse: 0.0144
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - classifier_head_accuracy: 0.9994 - loss: 0.0075 - regressor_head_mse: 0.0032 - val_classifier_head_accuracy: 0.8594 - val_loss: 0.7281 - val_regressor_head_mse: 0.0178
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - classifier_head_accuracy: 0.9750 - loss: 0.0717 - regressor_head_mse: 0.0064 - val_classifier_head_accuracy: 0.8750 - val_loss: 0.4989 - val_regressor_head_mse: 0.0234
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - classifier_head_accuracy: 0.9618 - loss: 0.1381 - regressor_head_mse: 0.0265 - val_classifier_head_accuracy: 0.5000 - val_loss: 4.6318 - val_regressor_head_mse: 0.0056
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 229ms/step - classifier_head_accuracy: 0.9873 - loss: 0.0466 - regressor_head_mse: 0.0096 - val_classifier_head_accuracy: 0.7656 - val_loss: 1.0582 - val_regressor_head_mse: 0.0160
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0139 - regressor_head_mse: 0.0057 - val_classifier_head_accuracy: 0.7969 - val_loss: 1.1462 - val_regressor_head_mse: 0.0165
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - classifier_head_accuracy: 0.9991 - loss: 0.0107 - regressor_head_mse: 0.0040 - val_classifier_head_accuracy: 0.8125 - val_loss: 0.5143 - val_regressor_head_mse: 0.0129
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0076 - regressor_head_mse: 0.0036 - val_classifier_head_accuracy: 0.8594 - val_loss: 0.7384 - val_regressor_head_mse: 0.0160
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - classifier_head_accuracy: 0.9989 - loss: 0.0051 - regressor_head_mse: 0.0027 - val_classifier_head_accuracy: 0.5000 - val_loss: 8.7001 - val_regressor_head_mse: 0.0067
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - classifier_head_accuracy: 0.9982 - loss: 0.0093 - regressor_head_mse: 0.0030 - val_classifier_head_accuracy: 0.8125 - val_loss: 1.4917 - val_regressor_head_mse: 0.0141
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - classifier_head_accuracy: 0.9933 - loss: 0.0230 - regressor_head_mse: 0.0037 - val_classifier_head_accuracy: 0.7656 - val_loss: 1.2761 - val_regressor_head_mse: 0.0169
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - classifier_head_accuracy: 0.9937 - loss: 0.0278 - regressor_head_mse: 0.0040 - val_classifier_head_accuracy: 0.8438 - val_loss: 0.5668 - val_regressor_head_mse: 0.0147
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 270ms/step - classifier_head_accuracy: 0.9946 - loss: 0.0191 - regressor_head_mse: 0.0044 - val_classifier_head_accuracy: 0.8438 - val_loss: 0.7747 - val_regressor_head_mse: 0.0154
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - classifier_head_accuracy: 0.9933 - loss: 0.0162 - regressor_head_mse: 0.0036 - val_classifier_head_accuracy: 0.5000 - val_loss: 7.4003 - val_regressor_head_mse: 0.0107
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0039 - regressor_head_mse: 0.0025 - val_classifier_head_accuracy: 0.7969 - val_loss: 1.2831 - val_regressor_head_mse: 0.0136
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0043 - regressor_head_mse: 0.0020 - val_classifier_head_accuracy: 0.8125 - val_loss: 1.2332 - val_regressor_head_mse: 0.0144
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0029 - regressor_head_mse: 0.0019 - val_classifier_head_accuracy: 0.8281 - val_loss: 0.6958 - val_regressor_head_mse: 0.0124
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0033 - regressor_head_mse: 0.0023 - val_classifier_head_accuracy: 0.8594 - val_loss: 0.8216 - val_regressor_head_mse: 0.0151
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0034 - regressor_head_mse: 0.0025 - val_classifier_head_accuracy: 0.5000 - val_loss: 9.2326 - val_regressor_head_mse: 0.0158
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0034 - regressor_head_mse: 0.0025 - val_classifier_head_accuracy: 0.7812 - val_loss: 1.3654 - val_regressor_head_mse: 0.0141
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0032 - regressor_head_mse: 0.0022 - val_classifier_head_accuracy: 0.8125 - val_loss: 1.2608 - val_regressor_head_mse: 0.0146
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0028 - regressor_head_mse: 0.0022 - val_classifier_head_accuracy: 0.8125 - val_loss: 0.7328 - val_regressor_head_mse: 0.0128
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0026 - regressor_head_mse: 0.0019 - val_classifier_head_accuracy: 0.8594 - val_loss: 0.8408 - val_regressor_head_mse: 0.0144
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0025 - regressor_head_mse: 0.0017 - val_classifier_head_accuracy: 0.5000 - val_loss: 9.2469 - val_regressor_head_mse: 0.0119
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 278ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0024 - regressor_head_mse: 0.0017 - val_classifier_head_accuracy: 0.7969 - val_loss: 1.4554 - val_regressor_head_mse: 0.0136
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0023 - regressor_head_mse: 0.0018 - val_classifier_head_accuracy: 0.8281 - val_loss: 1.2878 - val_regressor_head_mse: 0.0137
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 231ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0023 - regressor_head_mse: 0.0018 - val_classifier_head_accuracy: 0.8125 - val_loss: 0.7462 - val_regressor_head_mse: 0.0122
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0021 - regressor_head_mse: 0.0016 - val_classifier_head_accuracy: 0.8594 - val_loss: 0.8653 - val_regressor_head_mse: 0.0139
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0023 - regressor_head_mse: 0.0018 - val_classifier_head_accuracy: 0.5000 - val_loss: 9.7627 - val_regressor_head_mse: 0.0128
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0021 - regressor_head_mse: 0.0017 - val_classifier_head_accuracy: 0.7969 - val_loss: 1.4100 - val_regressor_head_mse: 0.0136
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0022 - regressor_head_mse: 0.0017 - val_classifier_head_accuracy: 0.8281 - val_loss: 1.2751 - val_regressor_head_mse: 0.0134
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 268ms/step - classifier_head_accuracy: 1.0000 - loss: 0.0021 - regressor_head_mse: 0.0015 - val_classifier_head_accuracy: 0.8125 - val_loss: 0.7405 - val_regressor_head_mse: 0.0114
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 261ms/step - classifier_head_accuracy: 0.9983 - loss: 0.0067 - regressor_head_mse: 0.0021 - val_classifier_head_accuracy: 0.7812 - val_loss: 0.9595 - val_regressor_head_mse: 0.0135
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 272ms/step - classifier_head_accuracy: 0.9957 - loss: 0.0143 - regressor_head_mse: 0.0035 - val_classifier_head_accuracy: 0.5000 - val_loss: 6.2476 - val_regressor_head_mse: 0.0153
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - classifier_head_accuracy: 0.9959 - loss: 0.0158 - regressor_head_mse: 0.0032 - val_classifier_head_accuracy: 0.7812 - val_loss: 1.4446 - val_regressor_head_mse: 0.0153
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - classifier_head_accuracy: 0.9948 - loss: 0.0238 - regressor_head_mse: 0.0047 - val_classifier_head_accuracy: 0.7969 - val_loss: 1.3209 - val_regressor_head_mse: 0.0170
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - classifier_head_accuracy: 0.9989 - loss: 0.0139 - regressor_head_mse: 0.0041 - val_classifier_head_accuracy: 0.7812 - val_loss: 0.7581 - val_regressor_head_mse: 0.0146
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - classifier_head_accuracy: 0.9952 - loss: 0.0164 - regressor_head_mse: 0.0039 - val_classifier_head_accuracy: 0.7969 - val_loss: 0.7448 - val_regressor_head_mse: 0.0166
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - classifier_head_accuracy: 0.9936 - loss: 0.0383 - regressor_head_mse: 0.0075 - val_classifier_head_accuracy: 0.5000 - val_loss: 6.6343 - val_regressor_head_mse: 0.0102
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - classifier_head_accuracy: 0.9913 - loss: 0.0360 - regressor_head_mse: 0.0075 - val_classifier_head_accuracy: 0.8125 - val_loss: 1.6625 - val_regressor_head_mse: 0.0192
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - classifier_head_accuracy: 0.9897 - loss: 0.0410 - regressor_head_mse: 0.0119 - val_classifier_head_accuracy: 0.8125 - val_loss: 1.0159 - val_regressor_head_mse: 0.0147
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - classifier_head_accuracy: 0.9945 - loss: 0.0233 - regressor_head_mse: 0.0043 - val_classifier_head_accuracy: 0.8125 - val_loss: 0.6042 - val_regressor_head_mse: 0.0141
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - classifier_head_accuracy: 0.9995 - loss: 0.0138 - regressor_head_mse: 0.0039 - val_classifier_head_accuracy: 0.8750 - val_loss: 0.7873 - val_regressor_head_mse: 0.0147
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - classifier_head_accuracy: 0.9998 - loss: 0.0070 - regressor_head_mse: 0.0030 - val_classifier_head_accuracy: 0.5000 - val_loss: 8.4374 - val_regressor_head_mse: 0.0116

# %% [markdown]
# The training performance can be checked in the charts below.

# %%
plt.plot(history.history['classifier_head_accuracy'])
plt.plot(history.history['val_classifier_head_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['classifier_head_loss'])
plt.plot(history.history['val_classifier_head_loss'])
plt.title('Classification Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 plt.plot(history.history['classifier_head_loss'])
#       2 plt.plot(history.history['val_classifier_head_loss'])
#       3 plt.title('Classification Loss')
#
# KeyError: 'classifier_head_loss'

# %%
plt.plot(history.history['regressor_head_mse'])
plt.plot(history.history['val_regressor_head_mse'])
plt.title('Bounding Box Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ## Evaluation
#
# The best way to evaluate the end model performance is by using IoU - intersection over Union - metrics. The following implementation of IoU was adapted from PyImage Search website:

# %%
# adapted from: https://pyimagesearch.com/2016/11/07/intersection-over-union-iou-for-object-detection/
def intersection_over_union(boxA, boxB):
	xA = max(boxA[0], boxB[0])
	yA = max(boxA[1], boxB[1])
	xB = min(boxA[0] + boxA[2], boxB[0] + boxB[2])
	yB = min(boxA[1] + boxA[3], boxB[1] + boxB[3])
	interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)
	boxAArea = (boxA[2] + 1) * (boxA[3] + 1)
	boxBArea = (boxB[2] + 1) * (boxB[3] + 1)
	iou = interArea / float(boxAArea + boxBArea - interArea)
	return iou

# %%
def tune_test_ds(dataset):
    dataset = dataset.map(format_instance, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(1) 
    dataset = dataset.repeat()
    return dataset

test_ds = tune_test_ds(raw_test_ds)

# %% [markdown]
# The model performance is finally evaluated on the test dataset. Green boxes indicaates correct classification in which the predicted label (masked-unmasked) matches with the actual label.
# A red box indicate a wrong classification.

# %%
plt.figure(figsize=(12, 10))

test_list = list(test_ds.take(20).as_numpy_iterator())

print(len(test_list))

image, labels = test_list[0]

for i in range(len(test_list)):

    ax = plt.subplot(4, 5, i + 1)
    image, labels = test_list[i]

    predictions = model(image)

    predicted_box = predictions[1][0] * input_size
    predicted_box = tf.cast(predicted_box, tf.int32)

    predicted_label = predictions[0][0]

    image = image[0]

    actual_label = labels[0][0]
    actual_box = labels[1][0] * input_size
    actual_box = tf.cast(actual_box, tf.int32)

    image = image.astype("float") * 255.0
    image = image.astype(np.uint8)
    image_color = cv.cvtColor(image, cv.COLOR_GRAY2RGB)

    color = (255, 0, 0)
    # print box red if predicted and actual label do not match
    if (predicted_label[0] > 0.5 and actual_label[0] > 0) or (predicted_label[0] < 0.5 and actual_label[0] == 0):
        color = (0, 255, 0)

    img_label = "unmasked"
    if predicted_label[0] > 0.5:
        img_label = "masked"

    predicted_box_n = predicted_box.numpy()
    cv.rectangle(image_color, predicted_box_n, color, 2)
    cv.rectangle(image_color, actual_box.numpy(), (0, 0, 255), 2)
    cv.rectangle(image_color, (predicted_box_n[0], predicted_box_n[1] + predicted_box_n[3] - 20), (predicted_box_n[0] + predicted_box_n[2], predicted_box_n[1] + predicted_box_n[3]), color, -1)
    cv.putText(image_color, img_label, (predicted_box_n[0] + 5, predicted_box_n[1] + predicted_box_n[3] - 5), cv.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 0))

    IoU = intersection_over_union(predicted_box.numpy(), actual_box.numpy())

    plt.title("IoU:" + format(IoU, '.4f'))
    plt.imshow(image_color)
    plt.axis("off")
# Out:
# 20

# %% [markdown]
# ## Conclusion
#
# Taking in consideration the small size of the data used for training and the fact of training the model from scratch without transfer learning, the results above are surprisingly good. We can think in ways to improve it even more:
#
# - The first option to improve the bound box and classificataion performance is increase the training data size which can be easily achieved by data augmentation.
#
# - Tweaking the hyperparameters and finding on way to improve the regularization can either improve the results, reducing the classification and regression errors.
#
# A good enhacement here would be calculating mAP comparing the results to one or more object detectors. Implementing other features like multiscale and multiple detections can also provide a solid understand of real challengings in developing an battle-tested object detector.
